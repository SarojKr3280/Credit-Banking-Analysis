# %%
import pandas as pd
import numpy as np
import sys

# %%
customer_df_raw  = pd.read_excel('Credit Banking_Project - 1.xls', sheet_name = 'Customer Acqusition') 
customer_df_raw
# Out:
#     Sl No: Customer        Age        City Credit Card Product   Limit  \
# 0        1       A1   0.928521   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  11.559307      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 0       C1  Self Employed
# 1       C2   Salaried_MNC
# 2       C3   Salaried_Pvt
# ...

# %%
customer_df  = pd.read_excel('Credit Banking_Project - 1.xls', sheet_name = 'Customer Acqusition') 
customer_df
# Out:
#     Sl No: Customer        Age        City Credit Card Product   Limit  \
# 0        1       A1   0.928521   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  11.559307      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 0       C1  Self Employed
# 1       C2   Salaried_MNC
# 2       C3   Salaried_Pvt
# ...

# %%
spend_df = pd.read_excel('Credit Banking_Project - 1.xls', sheet_name = 'Spend') 
spend_df
# Out:
#       Sl No: Costomer      Month        Type         Amount
# 0          1       A1 2004-01-12   JEWELLERY  473775.834869
# 1          2       A1 2004-01-03       PETRO  335578.666019
# 2          3       A1 2004-01-15     CLOTHES  371040.941912
# 3          4       A1 2004-01-25        FOOD  141177.813256
# 4          5       A1 2005-01-17      CAMERA  398403.771812
# ...      ...      ...        ...         ...            ...
# 1495    1496      A67 2006-02-04  BUS TICKET  195841.312215
# 1496    1497      A68 2006-03-25  BUS TICKET  284262.517709
# 1497    1498      A69 2006-03-31  BUS TICKET  206552.273598
# 1498    1499      A70 2006-03-23  BUS TICKET   41024.781283
# 1499    1500      A71 2006-03-24  BUS TICKET  101397.548588
#
# [1500 rows x 5 columns]

# %%
repayment_df = pd.read_excel('Credit Banking_Project - 1.xls', sheet_name = 'Repayment') 
repayment_df
# Out:
#       SL No: Costomer      Month         Amount
# 0          1       A1 2004-01-12  331844.007374
# 1          2       A1 2004-01-03  441139.807335
# 2          3       A1 2004-01-15   32480.004009
# 3          4       A1 2004-01-25   90636.966534
# 4          5       A1 2005-01-17    1581.969829
# ...      ...      ...        ...            ...
# 1495    1496      A67 2005-05-09  200288.874065
# 1496    1497      A68 2006-05-10  231194.702295
# 1497    1498      A69 2006-07-11  391195.615836
# 1498    1499      A70 2005-08-12  357629.618186
# 1499    1500      A71 2004-09-13  179771.745248
#
# [1500 rows x 4 columns]

# %%
# Rename the 'Costomer' column in both spend_df and repayment_df to 'Customer'

spend_df.rename(columns={'Costomer': 'Customer'}, inplace=True)
repayment_df.rename(columns={'Costomer': 'Customer'}, inplace=True)

# %%
# checking wheteher the data is duplicate or not 
print("customerDf\n", customer_df.duplicated())
print("\n")
print("spendDf\n", spend_df.duplicated())
print("\n")
print("repaymentDf\n" ,repayment_df.duplicated())
# Out:
# customerDf
#  0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool
#
#
# spendDf
#  0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool
#
#
# repaymentDf
#  0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
customer_df = pd.read_excel('Credit Banking_Project - 1.xls', sheet_name = 'Customer Acqusition') 

x = customer_df["Age"].mean()
print(x)

for i in customer_df.index:
    if customer_df.loc[i, 'Age'] < 18: 
        customer_df.loc[i, 'Age'] = x

customer_df
# Out:
# 40.14650487273873
#     Sl No: Customer        Age        City Credit Card Product   Limit  \
# 0        1       A1  40.146505   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  40.146505      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 0       C1  Self Employed
# 1       C2   Salaried_MNC
# ...

# %%
print(customer_df['Age'].mean())
# Out:
# 47.28032183784048

# %%
customer_df = pd.read_excel('Credit Banking_Project - 1.xls', sheet_name = 'Customer Acqusition') 

y = customer_df["Age"].median()
print(y)

for i in customer_df.index:
    if customer_df.loc[i, 'Age'] < 18: 
        customer_df.loc[i, 'Age'] = customer_df["Age"].median()

customer_df
# Out:
# 40.54568179757059
#     Sl No: Customer        Age        City Credit Card Product   Limit  \
# 0        1       A1  40.545682   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  40.549030      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 0       C1  Self Employed
# 1       C2   Salaried_MNC
# ...

# %%
print(customer_df["Age"].median())
# Out:
# 40.55237908445339

# %%
pd.options.display.max_rows = 1500

# %%
spend_df
# Out:
#       Sl No: Customer      Month          Type         Amount
# 0          1       A1 2004-01-12     JEWELLERY  473775.834869
# 1          2       A1 2004-01-03         PETRO  335578.666019
# 2          3       A1 2004-01-15       CLOTHES  371040.941912
# 3          4       A1 2004-01-25          FOOD  141177.813256
# 4          5       A1 2005-01-17        CAMERA  398403.771812
# 5          6       A1 2005-02-23       SANDALS  429084.568141
# 6          7       A1 2005-02-01           CAR  219341.961771
# 7          8       A8 2004-02-05          BIKE   60301.644710
# 8          9       A9 2005-02-28          AUTO  199770.925237
# 9         10      A10 2005-02-16      SHOPPING   71117.211995
# 10        11      A11 2005-02-23    AIR TICKET  285355.755339
# 11        12      A12 2005-02-03    BUS TICKET   94470.137527
# 12        13      A13 2006-02-04  TRAIN TICKET  116944.434572
# 13        14      A14 2006-03-25        RENTAL  252037.324063
# ...

# %%
# Ensure the date format is correct and extract month and year

spend_df['Month'] = pd.to_datetime(spend_df['Month'], format='%d-%b-%y')
spend_df['YearMonth'] = spend_df['Month'].dt.to_period('M')
spend_df
# Out:
#       Sl No: Customer      Month          Type         Amount YearMonth
# 0          1       A1 2004-01-12     JEWELLERY  473775.834869   2004-01
# 1          2       A1 2004-01-03         PETRO  335578.666019   2004-01
# 2          3       A1 2004-01-15       CLOTHES  371040.941912   2004-01
# 3          4       A1 2004-01-25          FOOD  141177.813256   2004-01
# 4          5       A1 2005-01-17        CAMERA  398403.771812   2005-01
# 5          6       A1 2005-02-23       SANDALS  429084.568141   2005-02
# 6          7       A1 2005-02-01           CAR  219341.961771   2005-02
# 7          8       A8 2004-02-05          BIKE   60301.644710   2004-02
# 8          9       A9 2005-02-28          AUTO  199770.925237   2005-02
# 9         10      A10 2005-02-16      SHOPPING   71117.211995   2005-02
# 10        11      A11 2005-02-23    AIR TICKET  285355.755339   2005-02
# 11        12      A12 2005-02-03    BUS TICKET   94470.137527   2005-02
# ...

# %%
# Ensure the date format is correct and extract month and year

repayment_df['Month'] = pd.to_datetime(repayment_df['Month'], format='%d-%b-%y')
repayment_df['YearMonth'] = repayment_df['Month'].dt.to_period('M')
repayment_df
# Out:
#       SL No: Customer      Month         Amount YearMonth
# 0          1       A1 2004-01-12  331844.007374   2004-01
# 1          2       A1 2004-01-03  441139.807335   2004-01
# 2          3       A1 2004-01-15   32480.004009   2004-01
# 3          4       A1 2004-01-25   90636.966534   2004-01
# 4          5       A1 2005-01-17    1581.969829   2005-01
# 5          6       A1 2005-02-23  357678.507744   2005-02
# 6          7       A1 2005-02-01  280990.709927   2005-02
# 7          8       A8 2004-02-05  117697.053061   2004-02
# 8          9       A9 2005-02-28    8047.300780   2005-02
# 9         10      A10 2005-02-16  407418.805366   2005-02
# 10        11      A11 2005-02-23  243698.715142   2005-02
# 11        12      A12 2005-02-03  227656.566154   2005-02
# 12        13      A13 2006-02-04  106283.127730   2006-02
# 13        14      A14 2006-03-25   96146.724399   2006-03
# 14        15      A15 2006-03-31   18442.564661   2006-03
# ...

# %%
# monthly spend of each customer

monthlySpend = spend_df.groupby(['Customer','YearMonth'])['Amount'].sum().astype(int).reset_index()
print(type(monthlySpend))
monthlySpend
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Customer YearMonth   Amount
# 0         A1   2004-01  1511172
# 1         A1   2004-02    41381
# 2         A1   2004-05   131196
# 3         A1   2005-01   398403
# 4         A1   2005-02  1404193
# 5         A1   2005-08   129388
# 6         A1   2005-11   457316
# 7         A1   2006-04   564506
# 8         A1   2006-10   220735
# 9        A10   2004-01   747428
# 10       A10   2004-03   435158
# 11       A10   2004-05   480728
# 12       A10   2005-02   357396
# 13       A10   2005-05   696067
# 14       A10   2005-11   484425
# 15       A10   2006-03   233741
# 16       A10   2006-04    60212
# 17       A10   2006-05   117295
# 18       A10   2006-07   267436
# 19       A10   2006-08   230894
# 20      A100   2004-01    42254
# 21       A11   2004-01   819544
# 22       A11   2004-02   501940
# 23       A11   2004-04   493104
# 24       A11   2005-02   492694
# 25       A11   2005-05   337785
# 26       A11   2005-06   412747
# ...

# %%
# monthly repayment of each customer

monthlyRepayment = repayment_df.groupby(['Customer', 'YearMonth'])['Amount'].sum().astype(int).reset_index()
print(type(monthlyRepayment))
monthlyRepayment
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Customer YearMonth   Amount
# 0         A1   2004-01  1362775
# 1         A1   2004-02   191180
# 2         A1   2005-01     1581
# 3         A1   2005-02  1199807
# 4         A1   2005-07   300581
# 5         A1   2005-11   278486
# 6         A1   2006-04   371273
# 7         A1   2006-09   108320
# 8         A1   2006-11    17931
# 9        A10   2004-01  1149997
# 10       A10   2004-03   266929
# 11       A10   2005-01   446068
# 12       A10   2005-02   910142
# 13       A10   2005-04   279491
# 14       A10   2005-05   895696
# 15       A10   2006-03   125956
# 16       A10   2006-04   430112
# 17       A10   2006-05   298502
# 18       A10   2006-07   427415
# 19      A100   2004-01   151141
# 20       A11   2004-01  1052386
# 21       A11   2005-02  1106038
# 22       A11   2005-05   674434
# 23       A11   2005-08   127001
# 24       A11   2006-03   160690
# 25       A11   2006-04  1135005
# 26       A11   2006-05   424846
# ...

# %%
#  Highest paying customers.

hpc = monthlyRepayment.sort_values(['YearMonth', 'Amount'], ascending = [True, False])
hpc.style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_839b7">
#   <thead>
#     <tr>
#       <th id="T_839b7_level0_col0" class="col_heading level0 col0" >Customer</th>
#       <th id="T_839b7_level0_col1" class="col_heading level0 col1" >YearMonth</th>
#       <th id="T_839b7_level0_col2" class="col_heading level0 col2" >Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_839b7_row0_col0" class="data row0 col0" >A41</td>
#       <td id="T_839b7_row0_col1" class="data row0 col1" >2004-01</td>
#       <td id="T_839b7_row0_col2" class="data row0 col2" >3026775</td>
#     </tr>
#     <tr>
#       <td id="T_839b7_row1_col0" class="data row1 col0" >A40</td>
#       <td id="T_839b7_row1_col1" class="data row1 col1" >2004-01</td>
#       <td id="T_839b7_row1_col2" class="data row1 col2" >2496299</td>
#     </tr>
#     <tr>
#       <td id="T_839b7_row2_col0" class="data row2 col0" >A43</td>
#       <td id="T_839b7_row2_col1" class="data row2 col1" >2004-01</td>
# ...

# %%
print(spend_df['Type'].duplicated())

# first 14 entries are unique. So these are the only categories.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33       True
# 34       True
# 35       True
# 36       True
# 37       True
# 38       True
# 39       True
# 40       True
# 41       True
# 42       True
# 43       True
# 44       True
# 45       True
# 46       True
# 47       True
# 48       True
# 49       True
# 50       True
# 51       True
# 52       True
# 53       True
# 54       True
# 55       True
# 56       True
# 57       True
# 58       True
# 59       True
# 60       True
# 61       True
# ...

# %%
print('The different categories are:')
print(spend_df['Type'].head(14))
# Out:
# The different categories are:
# 0        JEWELLERY
# 1            PETRO
# 2          CLOTHES
# 3             FOOD
# 4           CAMERA
# 5          SANDALS
# 6              CAR
# 7             BIKE
# 8             AUTO
# 9         SHOPPING
# 10      AIR TICKET
# 11      BUS TICKET
# 12    TRAIN TICKET
# 13          RENTAL
# Name: Type, dtype: object

# %%
monthlySpendCategory = spend_df.groupby(['Type','YearMonth'])['Amount'].sum().astype(int).reset_index().sort_values(['YearMonth','Amount'], ascending =[True, False])
monthlySpendCategory.style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a82e9">
#   <thead>
#     <tr>
#       <th id="T_a82e9_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_a82e9_level0_col1" class="col_heading level0 col1" >YearMonth</th>
#       <th id="T_a82e9_level0_col2" class="col_heading level0 col2" >Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a82e9_row0_col0" class="data row0 col0" >CAMERA</td>
#       <td id="T_a82e9_row0_col1" class="data row0 col1" >2004-01</td>
#       <td id="T_a82e9_row0_col2" class="data row0 col2" >14644500</td>
#     </tr>
#     <tr>
#       <td id="T_a82e9_row1_col0" class="data row1 col0" >FOOD</td>
#       <td id="T_a82e9_row1_col1" class="data row1 col1" >2004-01</td>
#       <td id="T_a82e9_row1_col2" class="data row1 col2" >11636530</td>
#     </tr>
#     <tr>
#       <td id="T_a82e9_row2_col0" class="data row2 col0" >SHOPPING</td>
#       <td id="T_a82e9_row2_col1" class="data row2 col1" >2004-01</td>
# ...

# %%
print('Category which spend more money: ')
csmm = monthlySpendCategory.groupby('YearMonth').apply(lambda x: x[x['Amount'] == x['Amount'].max()])
csmm.style.hide()
# Out:
# Category which spend more money:
# <style type="text/css">
# </style>
# <table id="T_d38c1">
#   <thead>
#     <tr>
#       <th id="T_d38c1_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_d38c1_level0_col1" class="col_heading level0 col1" >YearMonth</th>
#       <th id="T_d38c1_level0_col2" class="col_heading level0 col2" >Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d38c1_row0_col0" class="data row0 col0" >CAMERA</td>
#       <td id="T_d38c1_row0_col1" class="data row0 col1" >2004-01</td>
#       <td id="T_d38c1_row0_col2" class="data row0 col2" >14644500</td>
#     </tr>
#     <tr>
#       <td id="T_d38c1_row1_col0" class="data row1 col0" >BUS TICKET</td>
#       <td id="T_d38c1_row1_col1" class="data row1 col1" >2004-02</td>
#       <td id="T_d38c1_row1_col2" class="data row1 col2" >2051643</td>
#     </tr>
#     <tr>
#       <td id="T_d38c1_row2_col0" class="data row2 col0" >CAMERA</td>
# ...

# %%
# Calculate the due amount 

due_amount_df = monthlySpend.merge(monthlyRepayment, on=['Customer', 'YearMonth'], how='left', suffixes=('_spend', '_repay'))
due_amount_df
due_amount_df['DueAmount'] = due_amount_df['Amount_spend'] - due_amount_df['Amount_repay'].fillna(0)
due_amount_df
# Out:
#     Customer YearMonth  Amount_spend  Amount_repay  DueAmount
# 0         A1   2004-01       1511172     1362775.0   148397.0
# 1         A1   2004-02         41381      191180.0  -149799.0
# 2         A1   2004-05        131196           NaN   131196.0
# 3         A1   2005-01        398403        1581.0   396822.0
# 4         A1   2005-02       1404193     1199807.0   204386.0
# 5         A1   2005-08        129388           NaN   129388.0
# 6         A1   2005-11        457316      278486.0   178830.0
# 7         A1   2006-04        564506      371273.0   193233.0
# 8         A1   2006-10        220735           NaN   220735.0
# 9        A10   2004-01        747428     1149997.0  -402569.0
# 10       A10   2004-03        435158      266929.0   168229.0
# 11       A10   2004-05        480728           NaN   480728.0
# 12       A10   2005-02        357396      910142.0  -552746.0
# 13       A10   2005-05        696067      895696.0  -199629.0
# ...

# %%
# Filter out rows where DueAmount is negative

due_amount_df = due_amount_df[due_amount_df['DueAmount'] > 0]
due_amount_df
# Out:
#     Customer YearMonth  Amount_spend  Amount_repay  DueAmount
# 0         A1   2004-01       1511172     1362775.0   148397.0
# 2         A1   2004-05        131196           NaN   131196.0
# 3         A1   2005-01        398403        1581.0   396822.0
# 4         A1   2005-02       1404193     1199807.0   204386.0
# 5         A1   2005-08        129388           NaN   129388.0
# 6         A1   2005-11        457316      278486.0   178830.0
# 7         A1   2006-04        564506      371273.0   193233.0
# 8         A1   2006-10        220735           NaN   220735.0
# 10       A10   2004-03        435158      266929.0   168229.0
# 11       A10   2004-05        480728           NaN   480728.0
# 14       A10   2005-11        484425           NaN   484425.0
# 15       A10   2006-03        233741      125956.0   107785.0
# 19       A10   2006-08        230894           NaN   230894.0
# 22       A11   2004-02        501940           NaN   501940.0
# ...

# %%
# Calculate interest on due amount

due_amount_df['Interest'] = due_amount_df['DueAmount'] * 0.029
due_amount_df
# Out:
# C:\Users\91705\AppData\Local\Temp\ipykernel_16968\1484353650.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   due_amount_df['Interest'] = due_amount_df['DueAmount'] * 0.029
#     Customer YearMonth  Amount_spend  Amount_repay  DueAmount   Interest
# 0         A1   2004-01       1511172     1362775.0   148397.0   4303.513
# 2         A1   2004-05        131196           NaN   131196.0   3804.684
# 3         A1   2005-01        398403        1581.0   396822.0  11507.838
# 4         A1   2005-02       1404193     1199807.0   204386.0   5927.194
# 5         A1   2005-08        129388           NaN   129388.0   3752.252
# 6         A1   2005-11        457316      278486.0   178830.0   5186.070
# ...

# %%
due_amount_df[['Customer', 'YearMonth', 'DueAmount', 'Interest']]
# Out:
#     Customer YearMonth  DueAmount   Interest
# 0         A1   2004-01   148397.0   4303.513
# 2         A1   2004-05   131196.0   3804.684
# 3         A1   2005-01   396822.0  11507.838
# 4         A1   2005-02   204386.0   5927.194
# 5         A1   2005-08   129388.0   3752.252
# 6         A1   2005-11   178830.0   5186.070
# 7         A1   2006-04   193233.0   5603.757
# 8         A1   2006-10   220735.0   6401.315
# 10       A10   2004-03   168229.0   4878.641
# 11       A10   2004-05   480728.0  13941.112
# 14       A10   2005-11   484425.0  14048.325
# 15       A10   2006-03   107785.0   3125.765
# 19       A10   2006-08   230894.0   6695.926
# 22       A11   2004-02   501940.0  14556.260
# 23       A11   2004-04   493104.0  14300.016
# 26       A11   2005-06   412747.0  11969.663
# 27       A11   2005-08   326980.0   9482.420
# 30       A11   2006-06   462784.0  13420.736
# 31       A11   2006-09    92870.0   2693.230
# 32       A11   2006-11   261661.0   7588.169
# ...

# %%
monthlyProfit = due_amount_df.groupby('YearMonth')['Interest'].sum().astype(int).reset_index()
monthlyProfit
# Out:
#    YearMonth  Interest
# 0    2004-01    577723
# 1    2004-02    179315
# 2    2004-03     91546
# 3    2004-04    139858
# 4    2004-05     82054
# 5    2004-09     91544
# 6    2004-11     95829
# 7    2005-01    164964
# 8    2005-02    370686
# 9    2005-04    142960
# 10   2005-05    291676
# 11   2005-06    205566
# 12   2005-07     59396
# 13   2005-08    158686
# 14   2005-09     74481
# 15   2005-10     67811
# 16   2005-11    248955
# 17   2005-12     71185
# 18   2006-01     84424
# 19   2006-02    199521
# 20   2006-03    480587
# 21   2006-04    406504
# 22   2006-05    182230
# 23   2006-06    104225
# 24   2006-07    172634
# 25   2006-08     64692
# 26   2006-09     92836
# 27   2006-10     78689
# 28   2006-11    170797
# 29   2006-12     77000

# %%
customer_df['Segment'].duplicated().head(10)
# The result indicates 
# that those which are false are unique and different.
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Segment, dtype: bool

# %%
# segment in which people are spending more

customer_segment = customer_df[['Customer', 'Segment']] 
spend = spend_df[['Customer', 'YearMonth', 'Amount']] 
customer_segment_spend = pd.merge(customer_segment, spend, on='Customer', how='left') 

# Calculated total spending per segment
segment_spend = customer_segment_spend.groupby([ 'YearMonth','Segment'])['Amount'].sum().astype(int).reset_index()
segment_spend.sort_values(['YearMonth','Amount'], ascending  = [True, False])
# Out:
#     YearMonth        Segment    Amount
# 1     2004-01  Normal Salary  22394595
# 3     2004-01   Salaried_Pvt  14010086
# 2     2004-01   Salaried_MNC  13432288
# 4     2004-01  Self Employed  13408824
# 0     2004-01           Govt  11952838
# 6     2004-02  Normal Salary   2841896
# 9     2004-02  Self Employed   1645751
# 7     2004-02   Salaried_MNC   1277255
# 5     2004-02           Govt    784188
# 8     2004-02   Salaried_Pvt    757059
# 13    2004-03   Salaried_Pvt   1277309
# 14    2004-03  Self Employed    872351
# 11    2004-03  Normal Salary    832458
# 10    2004-03           Govt    529480
# 12    2004-03   Salaried_MNC    453128
# 17    2004-04   Salaried_MNC   2262437
# 16    2004-04  Normal Salary   2007181
# 18    2004-04   Salaried_Pvt    983813
# 19    2004-04  Self Employed    931094
# 15    2004-04           Govt    470954
# 20    2004-05           Govt   1593276
# 21    2004-05  Normal Salary    848681
# 22    2004-05   Salaried_MNC    731506
# ...

# %%
Segment_spend_max = segment_spend.sort_values(['YearMonth','Amount'])
Segment_spend_month_max = Segment_spend_max.groupby('YearMonth').apply(lambda x: x[x['Amount'] == x['Amount'].max()]).style.hide()
Segment_spend_month_max
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6b0d">
#   <thead>
#     <tr>
#       <th id="T_d6b0d_level0_col0" class="col_heading level0 col0" >YearMonth</th>
#       <th id="T_d6b0d_level0_col1" class="col_heading level0 col1" >Segment</th>
#       <th id="T_d6b0d_level0_col2" class="col_heading level0 col2" >Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d6b0d_row0_col0" class="data row0 col0" >2004-01</td>
#       <td id="T_d6b0d_row0_col1" class="data row0 col1" >Normal Salary</td>
#       <td id="T_d6b0d_row0_col2" class="data row0 col2" >22394595</td>
#     </tr>
#     <tr>
#       <td id="T_d6b0d_row1_col0" class="data row1 col0" >2004-02</td>
#       <td id="T_d6b0d_row1_col1" class="data row1 col1" >Normal Salary</td>
#       <td id="T_d6b0d_row1_col2" class="data row1 col2" >2841896</td>
#     </tr>
#     <tr>
#       <td id="T_d6b0d_row2_col0" class="data row2 col0" >2004-03</td>
# ...

# %%
segment_spend = customer_segment_spend.groupby('Segment')['Amount'].sum().astype(int).reset_index()
segment_spend
# Out:
#          Segment     Amount
# 0           Govt   67325630
# 1  Normal Salary  107707142
# 2   Salaried_MNC   63639488
# 3   Salaried_Pvt   71704311
# 4  Self Employed   70975475

# %%
customer_segment = customer_df[['Customer', 'Segment']] 
repayment = repayment_df[['Customer', 'YearMonth', 'Amount']] 
customer_segment_repayment = pd.merge(customer_segment, repayment, on='Customer', how='left') 

# Calculated total repayment per segment
segment_repayment = customer_segment_repayment.groupby([ 'Segment'])['Amount'].sum().astype(int).reset_index()
segment_repayment
# Out:
#          Segment     Amount
# 0           Govt   65171408
# 1  Normal Salary  107108892
# 2   Salaried_MNC   62597404
# 3   Salaried_Pvt   65779451
# 4  Self Employed   70551286

# %%
spend_repayment = pd.merge(segment_spend, segment_repayment, on='Segment', how='left', suffixes = ('_spent','_repaid'))
spend_repayment
spend_repayment['Profit'] = spend_repayment['Amount_spent'] - spend_repayment['Amount_repaid']
spend_repayment
# Out:
#          Segment  Amount_spent  Amount_repaid   Profit
# 0           Govt      67325630       65171408  2154222
# 1  Normal Salary     107707142      107108892   598250
# 2   Salaried_MNC      63639488       62597404  1042084
# 3   Salaried_Pvt      71704311       65779451  5924860
# 4  Self Employed      70975475       70551286   424189

# %%
# most profitable segement

profit = spend_repayment[['Segment', 'Profit']]
profit
# Out:
#          Segment   Profit
# 0           Govt  2154222
# 1  Normal Salary   598250
# 2   Salaried_MNC  1042084
# 3   Salaried_Pvt  5924860
# 4  Self Employed   424189

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(data = profit , x ='Segment', y ='Profit')
plt.title('Segment Wise Profit')
plt.xlabel('Segment')
plt.ylabel('Profit')
plt.xticks(rotation = 45)
plt.show()

# %%
customer_age = customer_df_raw[['Customer', 'Age']] 
spend = monthlySpend[['Customer', 'YearMonth', 'Amount']] 
customer_age_spend = pd.merge(customer_age, spend, on='Customer', how='left') 
customer_age_spend
# Out:
#     Customer        Age YearMonth   Amount
# 0         A1   0.928521   2004-01  1511172
# 1         A1   0.928521   2004-02    41381
# 2         A1   0.928521   2004-05   131196
# 3         A1   0.928521   2005-01   398403
# 4         A1   0.928521   2005-02  1404193
# 5         A1   0.928521   2005-08   129388
# 6         A1   0.928521   2005-11   457316
# 7         A1   0.928521   2006-04   564506
# 8         A1   0.928521   2006-10   220735
# 9         A2  35.534551   2004-01   735263
# 10        A2  35.534551   2004-04   317441
# 11        A2  35.534551   2004-11   351735
# 12        A2  35.534551   2005-02   412993
# 13        A2  35.534551   2005-09   433983
# 14        A2  35.534551   2006-02   258293
# 15        A2  35.534551   2006-04   126060
# 16        A2  35.534551   2006-05   442880
# 17        A2  35.534551   2006-11    73294
# 18        A3  11.559307   2004-01   647216
# 19        A3  11.559307   2005-02   302394
# 20        A3  11.559307   2005-04   471583
# ...

# %%
ageWiseSpend = customer_age_spend.groupby(['Age','Customer'])['Amount'].sum().astype(int).reset_index()
ageWiseSpend
# Out:
#           Age Customer   Amount
# 0    0.726493      A29  6491839
# 1    0.928521       A1  4858290
# 2    1.840485      A64   236570
# 3    3.379858      A63  1355222
# 4    4.061398      A55  4303901
# 5    4.143754      A10  4110780
# 6    4.234677      A75   169763
# 7    5.026450      A16  5944037
# 8    5.537829      A30  6484119
# 9    6.579394      A19  5567497
# 10   6.772363      A14  7247751
# 11   7.737083      A89   374361
# 12   8.054997      A39  8526670
# 13   8.985611      A65   871614
# 14  10.524981      A42  8665630
# 15  10.683339      A37  8017975
# 16  11.182481      A12  6848581
# 17  11.559307       A3  2871158
# 18  12.651992      A43  6210769
# 19  12.911575      A72   324334
# 20  15.339445      A53  3230669
# 21  16.979379      A68   721689
# 22  18.158058       A9  5064630
# 23  19.098781      A32  3680114
# 24  19.181051      A90   371699
# 25  20.611833      A97   164330
# 26  21.588666      A99   476020
# 27  22.680845      A15  4766795
# ...

# %%
for i in ageWiseSpend.index:
    if ageWiseSpend.loc[i, 'Age'] < 18: 
        ageWiseSpend.loc[i, 'Age'] = 'Infant'
    elif ageWiseSpend.loc[i, 'Age'] > 18 and ageWiseSpend.loc[i, 'Age'] < 30:
        ageWiseSpend.loc[i, 'Age'] = 'Youth'
    elif ageWiseSpend.loc[i, 'Age'] > 30 and ageWiseSpend.loc[i, 'Age'] < 60:
        ageWiseSpend.loc[i, 'Age'] = 'Adult'
    elif ageWiseSpend.loc[i, 'Age'] > 60:
        ageWiseSpend.loc[i, 'Age'] = 'Old'

ageWiseSpend
# Out:
#        Age Customer   Amount
# 0   Infant      A29  6491839
# 1   Infant       A1  4858290
# 2   Infant      A64   236570
# 3   Infant      A63  1355222
# 4   Infant      A55  4303901
# 5   Infant      A10  4110780
# 6   Infant      A75   169763
# 7   Infant      A16  5944037
# 8   Infant      A30  6484119
# 9   Infant      A19  5567497
# 10  Infant      A14  7247751
# 11  Infant      A89   374361
# 12  Infant      A39  8526670
# 13  Infant      A65   871614
# 14  Infant      A42  8665630
# 15  Infant      A37  8017975
# 16  Infant      A12  6848581
# 17  Infant       A3  2871158
# 18  Infant      A43  6210769
# 19  Infant      A72   324334
# 20  Infant      A53  3230669
# 21  Infant      A68   721689
# 22   Youth       A9  5064630
# 23   Youth      A32  3680114
# 24   Youth      A90   371699
# 25   Youth      A97   164330
# 26   Youth      A99   476020
# 27   Youth      A15  4766795
# 28   Youth      A59  5479198
# 29   Youth     A100    42254
# 30   Youth      A78   235000
# ...

# %%
ageGroupSpend = ageWiseSpend.groupby('Age')['Amount'].sum().astype(int).reset_index()
ageGroupSpend
# Out:
#       Age     Amount
# 0   Adult  107734682
# 1  Infant   93433219
# 2     Old  134095056
# 3   Youth   46088684

# %%
# Which age group is spending more money?

plt.figure(figsize=(10, 6))
sns.barplot(data=ageGroupSpend , x='Age', y='Amount')
plt.title('Total Spending by Age groups')
plt.xlabel('Age')
plt.ylabel('Total Spending Amount')
plt.xticks(rotation=45)
plt.show()
